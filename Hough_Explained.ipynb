# %%
import cv2
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
image = np.zeros((32,32),dtype='uint8')
image[25,5] = 255
image[10,20] = 255

plt.imshow(image,cmap='gray')

# %%
from math import cos,sin,pi
color=['r','g']
count=0
for x,y in [(25,5),(10,20)]:
  rho = []
  for theta in range(-90,90,5):
    rho.append(x*cos(theta*pi/180.)+y*sin(theta*pi/180.))
  plt.plot(range(-90,90,5),rho,color=color[count])
  count+=1
plt.xlabel("theta")
plt.ylabel("rho")
plt.scatter(45,21,s=40,color='k')
plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive/')

# %cd /content/drive/'My Drive'/'All_Repos'/Self-Driving-Car-NanoDegree/CarND-LaneLines-P1/CarND-LaneLines-P1
# !jupyter nbconvert --to markdown Hough_Explained.ipynb
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# /content/drive/My Drive/All_Repos/Self-Driving-Car-NanoDegree/CarND-LaneLines-P1/CarND-LaneLines-P1
# [NbConvertApp] Converting notebook Hough_Explained.ipynb to markdown
# [NbConvertApp] Support files will be in Hough_Explained_files/
# [NbConvertApp] Making directory Hough_Explained_files
# [NbConvertApp] Making directory Hough_Explained_files
# [NbConvertApp] Writing 795 bytes to Hough_Explained.md
